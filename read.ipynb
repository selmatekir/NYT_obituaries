# %%
import pickle
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
with open('gdrive/My Drive/Colab Notebooks/preprocessedNYT.pkl', 'rb') as f:
    data = pickle.load(f)

print(data)
# Out:
#                 person  gender  ... Category_Code Gender_Code
# 0        Cedric Benson    Male  ...             0           0
# 1      Katreese Barnes  Female  ...             0           1
# 2          Danny Cohen    Male  ...             2           0
# 3           Bill Konyk    Male  ...            15           0
# 4         Donald Klein    Male  ...             2           0
# ...                ...     ...  ...           ...         ...
# 5206  John Mack Carter    Male  ...             0           0
# 5207        Don Keefer    Male  ...             0           0
# 5208    Milton Cardona    Male  ...             0           0
# 5209     Alastair Reid    Male  ...             0           0
# 5210     John Slattery    Male  ...             0           0
#
# [5211 rows x 11 columns]

# %%
data.keys()
# Out:
# Index(['person', 'gender', 'article', 'scrubbed_article',
#        'article_description', 'job_keys', 'major_title', 'clean_articles',
#        'clean_scrubbed_article', 'Category_Code', 'Gender_Code'],
#       dtype='object')

# %%
print(data.get('scrubbed_article'))
# Out:
# 0       _ was 36._ friends and family told The Austin ...
# 1       _ was 56._ brother Jerry said the cause was br...
# 2       _ was 81._ son, David, said the cause was Park...
# 3       _ was 88._ youngest son, Mark, said the cause ...
# 4       _ was 90._ wife, Rachel Klein, said the cause ...
#                               ...
# 5206    _ was 86.The cause was Parkinson’s disease, _ ...
# 5207    _ was the son of Willy Loman’s neighbor in the...
# 5208    _ was 69.The cause was heart failure, said _ w...
# 5209    _ was 88.The cause was a gastric bleed _ suffe...
# 5210    _ was 63.WCBS, the local station where _ had w...
# Name: scrubbed_article, Length: 5211, dtype: object
